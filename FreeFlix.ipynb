# %%
Price=[]
MY_LIST=[]

# %%
print('===================xxx=>  FreeFlixx  <=xxx=====================')
print('|         (Entertaiment Entertaiment Entertainment)           |')
print('===============================================================\n')

name=input('Hello: ') 

print("=======================> LOGIN <======================")
print("1.Login Id")
print("2.Name")
print("3.Password")
print("4.Logout")
print("=======================List Of Categories===========================")
def Movies():
    print('[1] Movies')
    print('[2] Rental Movies')
    print('[3] Subscription')
    print('[0] Exit')
    print("==================================================================")
Movies() 


option=int(input('Enter the choice: '))
while option !=0:
    
    if option==1:
        def m_menu():
        
        
            print('[1]Dangal')
            print('[2]Padman')
            print('[3]3 Idiots')
            print('[4]Don')
            print('[5]Jai Ho')
            print('[6]Golmaal')
            print('[7]Hera Pheri')
            print('[8]Gajni')
            print('[9]Bhoolbhulaya')
            print('[10]Agnipath')
            print('[0]Exit')
            print("="*53)
        
        m_menu()
        option2=int(input('Enter the choice: '))
        while option2 !=0:
                if option2 ==1:
                    print('Dangle Added To List')
                    print("="*53)
                    break
                
                
                elif option2 ==2:
                    print('Padman Added to List')
                    print("="*53)
                    break
                    
                elif option2 ==3:
                    print('3 Idiots Added to List')
                    print("="*53)
                    break
                elif option2 ==4:
                    print('Don Added to List')
                    print("="*53)
                    break
                elif option2 ==5:
                    print('Jai Ho Added to List') 
                    print("="*53)
                    break
                elif option2 ==6:
                    print('Golmaal Added to List')
                    print("="*53)
                    break
                elif option2 ==7:
                    print('Hera Pheri Added to List')
                    print("="*53)
                    break
                elif option2 ==8:
                    print('Gajni Added to List')
                    print("="*53)
                    break
                elif option2 ==9:
                    print('Bhulbhulaya Added to List')
                    print("="*53)
                    break
                elif option2 ==10:
                    print('Agnipath Added to List')
                    print("="*53)
                    break
                elif option2 ==0:
                    print('EXIT from Movies')
                    print("="*53)
                    break
                  
                
            
            
    

    
    
    

    
    

    elif option==2:
        def rental():
            
            print('[1]Stranger Things----------50')
            print('[2]Never Have I Ever----------45')
            print('[3]Sacred Games----------60')
            print('[4]Mirzapur----------65')
            print('[5]City of Dreams----------40')
            print('[6]Game of Thrones----------70')
            print('[7]Inside Edge----------40')
            print('[8]Vikings----------65')
            print('[9]Peaky Blinders----------60')
            print('[10]Lost In Space----------55')
            print('[0]Exit')
            print("="*53)
            
        
        
        rental()
        option3= int(input("Enter the Choice: "))
        while option3!=0:
            
            if option3 == 1:
                MY_LIST.append('Stranger_Things')
                print("Stranger Things Added To List")
                Price.append(50)
                print('Price=50')
                print("="*53)
                break
            elif option3 == 2:
                MY_LIST.append('Never_Have_I_Ever')
                print("Never Have I Ever Added To List")
                Price.append(45)
                print('Price=45')
                print("="*53)
                break
            elif option3 ==3:
                MY_LIST.append('Sacred_Games')
                print("Sacred Games Added To List")
                Price.append(60)
                print('Price=60')
                print("="*53)
                break
            elif option3 == 4:
                MY_LIST.append('Mirzapur')
                print("Mirzapur Added To List")
                Price.append(65)
                print('Price=65')
                print("="*53)
                break
            elif option3 == 5:
                MY_LIST.append('City_of_Dreams')
                print("City of Dreams Added to List")
                Price.append(40)
                print('Price=40')
                print("="*53)
                break
            elif option3 == 6:
                MY_LIST.append('Game_of_Thrones')
                print("Game of Thrones Added To List")
                Price.append(70)
                print('Price=70')
                print("="*53)
                break
            elif option3 == 7:
                MY_LIST.append('Inside_Edge')
                print("Inside Edge Added To List")
                Price.append(40)
                print('Price=40')
                print("="*53)
                break
            elif option3 == 8:
                MY_LIST.append('Vikings')
                print("Vikings Added To List")
                Price.append(65)
                print('Price=65')
                print("="*53)
                break
            elif option3 == 9:
                MY_LIST.append('Peaky_Blinders')
                print("Peaky Blinders Added To List")
                Price.append(60)
                print("="*53)
                break
            elif option3 ==10:
                MY_LIST.append('Lost_In_Space')
                print("Lost In Space Added To List")
                Price.append(55)
                print('Price=55')
                print("="*53)
                break
            elif option3 ==0:
                print("="*53)
                print('EXIT from Rental Movies')
                print("="*53)
                break
               
                
    
    
    
    
    
    
    


    
    elif option==3:
        def subscription():
            
            print('[1] NETFIX----------600')
            print('[2] AMAZON PRIME----------550')
            print('[3] HOTSTAR----------550')
            print('[4] YOUTUBE PREMIUM----------600')
            print('[5] VOOT----------400')
            print('[0]Exit')
            print("="*53)
            
        subscription()
        option4= int(input("Enter the Choice: "))
        while option4!=0:
            
            if option4 == 1:
                MY_LIST.append('NETFLIX')
                print("NETFLIX Added To List")
                Price.append(600)
                print('Price=600')
                print("="*53)
                break
                
            elif option4 ==2:
                MY_LIST.append('AMAZON_PRIME')
                print("AMAZON PRIME Added To List")
                Price.append(550)
                print('Price=550')
                print("="*53)
                break
                
            elif option4 ==3:
                MY_LIST.append('HOTSTAR')
                print("HOTSTAR Added To List")
                Price.append(550)
                print('Price=550')
                print("="*53)
                break
            
            elif option4 ==4:
                MY_LIST.append('YOUTUBE_PREMIUM')
                print("YOUTUBE PREMIUM Added To List")
                Price.append(600)
                print('Price=600')
                print("="*53)
                break
                
            elif option4 ==5:
                MY_LIST.append('VOOT')
                print("VOOT Added To List")
                Price.append(400)
                print('Price=400')
                print("="*53)
                break
                
            elif option4 ==0:
                    print('EXIT from Subscription')
                    print("="*53)
                    break



    
    
    
    
    
    
    
    
    
    
    
    
    
    Movies() 
    option=int(input('Enter the choice: '))


  

   
Movies()
option=int(input('Enter the choice: '))
# Out:
# ===================xxx=>  FreeFlixx  <=xxx=====================
# |         (Entertaiment Entertaiment Entertainment)           |
# ...
#
# Hello: Steve JObs
# =======================> LOGIN <======================
# 1.Login Id
# 2.Name
# 3.Password
# 4.Logout
# =======================List Of Categories===========================
# [1] Movies
# [2] Rental Movies
# [3] Subscription
# [0] Exit
# ...
# Enter the choice: 1
# [1]Dangal
# [2]Padman
# [3]3 Idiots
# [4]Don
# [5]Jai Ho
# [6]Golmaal
# [7]Hera Pheri
# [8]Gajni
# [9]Bhoolbhulaya
# [10]Agnipath
# [0]Exit
# ...
# Enter the choice: 0
# [1] Movies
# [2] Rental Movies
# [3] Subscription
# [0] Exit
# ...
# Enter the choice: 2
# [1]Stranger Things----------50
# [2]Never Have I Ever----------45
# [3]Sacred Games----------60
# [4]Mirzapur----------65
# [5]City of Dreams----------40
# [6]Game of Thrones----------70
# [7]Inside Edge----------40
# [8]Vikings----------65
# [9]Peaky Blinders----------60
# [10]Lost In Space----------55
# [0]Exit
# ...

# %%
Price
# Out:
# [50, 600]

# %%
total=0
for i in Price:
    total += i
    print(i)
print('total :',total)
# Out:
# 50
# 600
# total : 650

# %%
print ("===================>>>   RECEIPT   <<<===============")
for i in MY_LIST:
    print("   ",i)

print("="*53)
print("     Price :  {}" .format(Price))
print("     total :  {} ".format(total))
# Out:
# ===================>>>   RECEIPT   <<<===============
#     Stranger_Things
#     NETFLIX
# ...
#      Price :  [50, 600]
#      total :  650
